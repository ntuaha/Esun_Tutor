# %% [markdown]
# ## 簡介
# 就是來畫圖吧

# %%
import numpy as np
import matplotlib as mp
import pandas as pd
# %matplotlib inline
import sklearn
import os
import sys
import datetime
import random

# %% [markdown]
# ## 9.1 畫散佈圖
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html

# %%
a = np.random.random((10,2))
a
# Out:
# array([[ 0.61307254,  0.78671994],
#        [ 0.87238492,  0.35490978],
#        [ 0.45743013,  0.34422525],
#        [ 0.04188539,  0.41911437],
#        [ 0.64769776,  0.41386996],
#        [ 0.3623801 ,  0.44901848],
#        [ 0.37654032,  0.24682081],
#        [ 0.13973608,  0.99213375],
#        [ 0.83066669,  0.59358773],
#        [ 0.06651642,  0.25582038]])

# %%
import matplotlib.pyplot as plt
plt.plot(a[:,0],a[:,1],'o')
plt.show()

# %%
pd.DataFrame(a).plot(x=0,y=1,kind='scatter')

# %% [markdown]
# ## 9.2為圖形加上標籤
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html

# %%
plt.title('hi')
plt.xlabel('lol')
plt.plot(a[:,0],a[:,1],'o')
plt.show()

# %% [markdown]
# ## 9.3 為圖形加上網格

# %%
plt.title('hi')
plt.xlabel('lol')
plt.plot(a[:,0],a[:,1],'o')
plt.grid()
plt.show()

# %% [markdown]
# ## 9.4 畫多組散布圖
# https://matplotlib.org/examples/pylab_examples/subplots_demo.html

# %%
a = np.random.random(10)
b = np.random.random(10)
c = np.random.randint(0,2,10)

# %%
df = pd.DataFrame({'a':a,'b':b,"c":c})
df
# Out:
#           a         b  c
# 0  0.117321  0.633481  0
# 1  0.834453  0.688269  1
# 2  0.920320  0.229584  1
# 3  0.293783  0.567799  1
# 4  0.398146  0.184867  1
# 5  0.231036  0.730061  1
# 6  0.995887  0.114997  0
# 7  0.717150  0.210142  1
# 8  0.011040  0.819029  0
# 9  0.480544  0.030793  1

# %%
df[df['c']==1]
# Out:
#           a         b  c
# 1  0.834453  0.688269  1
# 2  0.920320  0.229584  1
# 3  0.293783  0.567799  1
# 4  0.398146  0.184867  1
# 5  0.231036  0.730061  1
# 7  0.717150  0.210142  1
# 9  0.480544  0.030793  1

# %%
f,(ax1,ax2) = plt.subplots(1,2,sharey=True,sharex=True)
df[df['c']==1].plot(x='a',y='b',ax=ax1,kind='scatter')
df[df['c']==0].plot(x='a',y='b',ax=ax2,kind='scatter')

# %% [markdown]
# ## 9.5 增加圖例
# https://matplotlib.org/users/legend_guide.html

# %%
line1, = plt.plot([1,2,3], label="Line 1", linestyle='--')
line2, = plt.plot([3,2,1], label="Line 2", linewidth=4)

# Create a legend for the first line.
first_legend = plt.legend(handles=[line1], loc=1)

# Add the legend manually to the current Axes.
ax = plt.gca().add_artist(first_legend)

# Create another legend for the second line.
plt.legend(handles=[line2], loc=4)

plt.show()

# %% [markdown]
# ## 10.6 畫出散布圖的回歸線
# https://stackoverflow.com/questions/6148207/linear-regression-with-matplotlib-numpy

# %%
x = [1,2,3,4]
y = [3,5,7,10] # 10, not 9, so the fit isn't perfect

# %%
fit = np.polyfit(x,y,1)
fit
# Out:
# array([ 2.3,  0.5])

# %%
# fit_fn is now a function which takes in x and returns an estimate for y
fit_fn = np.poly1d(fit) 
fit_fn
# Out:
# poly1d([ 2.3,  0.5])

# %%
plt.plot(x,y, 'yo', x, fit_fn(x), '--k')
plt.xlim(0, 5)
plt.ylim(0, 12)
plt.show()

# %% [markdown]
# ## 10.7 繪製所有變數的散佈圖
# https://stackoverflow.com/questions/7941207/is-there-a-function-to-make-scatterplot-matrices-in-matplotlib
# 但看起來沒有更好的解法

# %% [markdown]
# ## 9.8 繪製變數分組散佈圖

# %% [markdown]
# ## 9.9  繪製長條圖
# https://matplotlib.org/1.2.1/examples/pylab_examples/histogram_demo.html

# %% [markdown]
# ## 9.10加上信賴區間
